# %% [markdown]
# ### Exercise 01.2

# %% [markdown]
# 1. <font color="red">Aggiungere due distribuzioni di probabilità</font> utilizzando il **Metodo dell'inversione della distribuzione cumulativa** per campionare da una **generica** <font color="red">distribuzione esponenziale</font>, $p(x) = \lambda \exp(-\lambda x)$, $x\in [0;+\infty]$, e una **generica** <font color="red">distribuzione di Cauchy-Lorentz </font> $p(x)=\frac{1}{\pi}\frac{\Gamma}{(x-\mu)^2+\Gamma^2}$, $x\in [-\infty;+\infty]$.
# 2. <font color="red">Fare 3 istogrammi</font> "riempiti con" $10^4$ realizzazioni di $S_N = \frac{1}{N}\sum_{i=1}^N x_i$ (for $N=1, 2, 10, 100$), con $x_i$ variabile random ottenuta lanciando un dado *standard* (fig.1), un dado *exponential* (fig.2, uso $\lambda=1$) e un dado *Lorentzian*  (fig.3, uso $\mu=0$ e $\Gamma=1$).

# %% [markdown]
# ### Random

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.pyplot import *
from matplotlib import rc

br1,vr1,be1,ve1,bl1,vl1= np.loadtxt("isto_1.dat", delimiter=' ',unpack=True)
br2,vr2,be2,ve2,bl2,vl2= np.loadtxt("isto_2.dat", delimiter=' ',unpack=True)
br10,vr10,be10,ve10,bl10,vl10 = np.loadtxt("isto_10.dat", delimiter=' ',unpack=True)
br100,vr100,be100,ve100,bl100,vl100 = np.loadtxt("isto_100.dat", delimiter=' ',unpack=True)


plt.subplot(221)
plt.bar(br1,vr1,align = 'edge', width=0.02)
plt.title('random n=1')
plt.grid(True)

plt.subplot(222)
plt.bar(br2,vr2,align = 'edge', width=0.02)
plt.title('random n=2')
plt.grid(True)

plt.subplot(223)
plt.bar(br10,vr10,align = 'edge', width=0.02)
plt.title('random n=10')
plt.grid(True)

plt.subplot(224)
plt.bar(br100,vr100,align = 'edge', width=0.02)
plt.title('random n=100')
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())
plt.subplots_adjust(top=0.95, bottom=0.0, left=0.10, right=0.95, hspace=0.3,wspace=0.3)

plt.show()

# %% [markdown]
# ### Esponenziale

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.pyplot import *
from matplotlib import rc

br1,vr1,be1,ve1,bl1,vl1= np.loadtxt("isto_1.dat", delimiter=' ',unpack=True)
br2,vr2,be2,ve2,bl2,vl2= np.loadtxt("isto_2.dat", delimiter=' ',unpack=True)
br10,vr10,be10,ve10,bl10,vl10 = np.loadtxt("isto_10.dat", delimiter=' ',unpack=True)
br100,vr100,be100,ve100,bl100,vl100 = np.loadtxt("isto_100.dat", delimiter=' ',unpack=True)


plt.subplot(221)
plt.bar(be1,ve1,align = 'edge', width=0.1)
plt.title('Esponenziale n=1')
plt.grid(True)

plt.subplot(222)
plt.bar(be2,ve2,align = 'edge', width=0.1)
plt.title('Esponenziale n=2')
plt.grid(True)

plt.subplot(223)
plt.bar(be10,ve10,align = 'edge', width=0.1)
plt.title('Esponenziale n=10')
plt.grid(True)

plt.subplot(224)
plt.bar(be100,ve100,align = 'edge', width=0.1)
plt.title('Esponenziale n=100')
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())
plt.subplots_adjust(top=0.95, bottom=0.0, left=0.10, right=0.95, hspace=0.3,wspace=0.3)

plt.show()

# %% [markdown]
# ### Lorenziana

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.pyplot import *
from matplotlib import rc

br1,vr1,be1,ve1,bl1,vl1= np.loadtxt("isto_1.dat", delimiter=' ',unpack=True)
br2,vr2,be2,ve2,bl2,vl2= np.loadtxt("isto_2.dat", delimiter=' ',unpack=True)
br10,vr10,be10,ve10,bl10,vl10 = np.loadtxt("isto_10.dat", delimiter=' ',unpack=True)
br100,vr100,be100,ve100,bl100,vl100 = np.loadtxt("isto_100.dat", delimiter=' ',unpack=True)


plt.figure(3)

plt.subplot(221)
plt.bar(bl1,vl1,align = 'edge', width=0.3)
plt.title('Lorenziana n=1')
plt.grid(True)

plt.subplot(222)
plt.bar(bl2,vl2,align = 'edge', width=0.3)
plt.title('Lorenziana n=2')
plt.grid(True)

plt.subplot(223)
plt.bar(bl10,vl10,align = 'edge', width=0.3)
plt.title('Lorenziana n=10')
plt.grid(True)

plt.subplot(224)
plt.bar(bl100,vl100,align = 'edge', width=0.3)
plt.title('Lorenziana n=100')
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())
plt.subplots_adjust(top=0.95, bottom=0.0, left=0.10, right=0.95, hspace=0.3, wspace=0.3)

plt.show()

# %% [markdown]
# ### Metodo dell'inversione della distribuzione

# %% [markdown]
# *Definizione :* Data un distribuzione di probabilità 1D $p(x)$ definita su $-\infty<x<+\infty$ la *funzione  di distribuzione cumulativa* $F(x)$ è definita come :
# $$ F(x) = \int_{-\infty}^{x} dz \, p(x')dx'. $$
#
# Trovata la distribuzione analitca e assegnando $y=F(x) \in [0,1]$ si può trovare i valori di x estratti secondo la distribuzione richiesta.
# $F(x)$ deve essere invertibile analiticamente per utilizzare questo metodo.

# %% [markdown]
# *Lorentziana :*
#     $$ x = \Gamma tan\big[\pi \big(y-\frac{1}{2}\big ) \big]$$
#
# *Esponenziale :*
#     $$ x = -\frac{1}{\lambda} \ln(1-y)$$
