# %% [markdown]
# ### Esercizio 08.3
#
# Usare il codice PIMC/PIGS per studiare lo stesso sistema.Usare PIGS ($T=0$) per cercare
#
# - una funzione d'onda costante, $\Psi_T(x)=1$
# - usare $\Psi_T(x) = \Psi_T^{\sigma,\mu}(x)$ con i valori trovati.
#
# <span style="color:red">Comparare i risultati con il codice VMC</span>.
#
# <span style="color:red">Usare infine il codice PIMC ($T>0$) .</span>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit
import subprocess
from shutil import *
from glob import glob

x,y,erry = np.loadtxt("probabilitywave.dat", delimiter=' ', unpack=True)
plt.bar(x,y,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con PIGS ')

plt.show()

# %%
#T=[1.0,5.0,12.0,18.0,30.0]
T=[200.,100.]

with open('input.dat', 'r') as file:
	data = file.readlines()

for i in range(len(T)):
	data[1] = str(T[i]) + "\n" 
	with open('input.dat', 'w') as file:
		file.writelines(data)
	cmd = "./qmc1d"
	value = subprocess.call(cmd, shell = True)

# %%
x,y,erry = np.loadtxt("prob_1.dat", delimiter=' ', unpack=True)
x1,y1,erry1 = np.loadtxt("prob_5.dat", delimiter=' ', unpack=True)
x2,y2,erry2 = np.loadtxt("prob_12.dat", delimiter=' ', unpack=True)
x3,y3,erry3 = np.loadtxt("prob_18.dat", delimiter=' ', unpack=True)
x4,y4,erry4 = np.loadtxt("prob_30.dat", delimiter=' ', unpack=True)
x5,y5,erry5 = np.loadtxt("prob_40.dat", delimiter=' ', unpack=True)
x6,y6,erry6 = np.loadtxt("prob_50.dat", delimiter=' ', unpack=True)
x7,y7,erry7 = np.loadtxt("prob_60.dat", delimiter=' ', unpack=True)
x8,y8,erry8 = np.loadtxt("prob_50.dat", delimiter=' ', unpack=True)


plt.figure(figsize=(15,20))

plt.subplot(521) 
plt.bar(x,y,yerr=erry,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=1$')

plt.subplot(522) 
plt.bar(x1,y1,yerr=erry1,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=5$ ')

plt.subplot(523) 
plt.bar(x2,y2,yerr=erry2,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=12$ ')

plt.subplot(524) 
plt.bar(x3,y3,yerr=erry3,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=18$ ')

plt.subplot(525) 
plt.bar(x4,y4,yerr=erry4,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=30$ ')

plt.subplot(526) 
plt.bar(x5,y5,yerr=erry5,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=40$ ')

plt.subplot(527) 
plt.bar(x6,y6,yerr=erry6,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=50$ ')

plt.subplot(528) 
plt.bar(x7,y7,yerr=erry7,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=60$ ')

plt.subplot(529) 
plt.bar(x8,y8,yerr=erry8,align = 'edge', width=0.025)
plt.xlabel('x')
plt.ylabel('$number$')
plt.title('$|\phi(x)|^{2}$ istogramma con $T=100$ ')



plt.show()
